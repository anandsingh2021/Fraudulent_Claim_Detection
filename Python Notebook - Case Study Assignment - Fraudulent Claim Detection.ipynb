# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix

from sklearn.model_selection import cross_val_score

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('C:/Users/anand/Downloads/Starter+Notebook+++Data/Starter Notebook + Data/insurance_claims.csv')

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values

# Droping the column '_c39' as it contains only null values ~1000 nos
df.drop(['_c39'], axis=1, inplace=True)
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (1000, 39)

# %%
# Droping rows where 'authorities_contacted' is null
df = df[df['authorities_contacted'].notnull()]
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 5                 256   39         104594       2006-10-12           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 5    250/500               1000                1351.10               0
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 5       478456  ...         2                      NO              64100
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 5         6410           6410          51280       Saab         95      2003
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 5              Y
#
# [5 rows x 39 columns]

# %%
# Re-check for missing values in each column
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 5                 256   39         104594       2006-10-12           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 5    250/500               1000                1351.10               0
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 5       478456  ...         2                      NO              64100
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 5         6410           6410          51280       Saab         95      2003
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 5              Y
#
# [5 rows x 39 columns]

# %%
df['months_as_customer'].value_counts()
# Out:
# months_as_customer
# 285    7
# 128    7
# 254    7
# 230    7
# 259    6
#       ..
# 60     1
# 447    1
# 414    1
# 352    1
# 17     1
# Name: count, Length: 384, dtype: int64

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"Unique Values Count: {df[col].nunique()}")
    print(f"Value Counts:\n{df[col].value_counts(dropna=False).head(10)}")
# Out:
# Column: months_as_customer
# Unique Values Count: 384
# Value Counts:
# months_as_customer
# 285    7
# 128    7
# 254    7
# 230    7
# 259    6
# 222    6
# 257    6
# 147    6
# 107    6
# 156    6
# Name: count, dtype: int64
#
# Column: age
# Unique Values Count: 46
# Value Counts:
# age
# 43    45
# 41    43
# 39    43
# 38    40
# 37    39
# 30    38
# 32    36
# 34    36
# 31    35
# 33    35
# Name: count, dtype: int64
#
# Column: policy_number
# Unique Values Count: 909
# Value Counts:
# policy_number
# 521585    1
# 797634    1
# 261905    1
# 674485    1
# 223404    1
# 991480    1
# 804219    1
# 483088    1
# 100804    1
# 941807    1
# Name: count, dtype: int64
#
# Column: policy_bind_date
# Unique Values Count: 865
# Value Counts:
# policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1992-01-05    2
# 2002-12-21    2
# 1990-06-24    2
# 2007-05-06    2
# 2014-07-27    2
# 1997-02-03    2
# 1998-01-29    2
# Name: count, dtype: int64
#
# Column: policy_state
# Unique Values Count: 3
# Value Counts:
# policy_state
# OH    319
# IL    310
# IN    280
# Name: count, dtype: int64
#
# Column: policy_csl
# Unique Values Count: 3
# Value Counts:
# policy_csl
# 100/300     326
# 250/500     316
# 500/1000    267
# Name: count, dtype: int64
#
# Column: policy_deductable
# Unique Values Count: 3
# Value Counts:
# policy_deductable
# 1000    317
# 500     315
# 2000    277
# Name: count, dtype: int64
#
# Column: policy_annual_premium
# Unique Values Count: 903
# Value Counts:
# policy_annual_premium
# 1362.87    2
# 1215.36    2
# 1524.45    2
# 1374.22    2
# 1558.29    2
# 1281.25    2
# 1133.27    1
# 1422.95    1
# 671.01     1
# 895.14     1
# Name: count, dtype: int64
#
# Column: umbrella_limit
# Unique Values Count: 11
# Value Counts:
# umbrella_limit
# 0           726
# 6000000      50
# 5000000      43
# 4000000      37
# 7000000      24
# 3000000      11
# 8000000       8
# 9000000       4
# 2000000       3
# 10000000      2
# Name: count, dtype: int64
#
# Column: insured_zip
# Unique Values Count: 904
# Value Counts:
# insured_zip
# 477695    2
# 469429    2
# 456602    2
# 431202    2
# 446895    2
# 440720    1
# 609949    1
# 439964    1
# 478486    1
# 466498    1
# Name: count, dtype: int64
#
# Column: insured_sex
# Unique Values Count: 2
# Value Counts:
# insured_sex
# FEMALE    494
# MALE      415
# Name: count, dtype: int64
#
# Column: insured_education_level
# Unique Values Count: 7
# Value Counts:
# insured_education_level
# High School    146
# JD             145
# MD             132
# Masters        130
# Associate      129
# PhD            115
# College        112
# Name: count, dtype: int64
#
# Column: insured_occupation
# Unique Values Count: 14
# Value Counts:
# insured_occupation
# machine-op-inspct    87
# prof-specialty       77
# tech-support         71
# craft-repair         70
# sales                70
# exec-managerial      68
# transport-moving     67
# priv-house-serv      66
# other-service        61
# armed-forces         59
# Name: count, dtype: int64
#
# Column: insured_hobbies
# Unique Values Count: 20
# Value Counts:
# insured_hobbies
# reading           58
# exercise          54
# bungie-jumping    52
# camping           50
# movies            50
# hiking            50
# yachting          49
# paintball         49
# golf              47
# skydiving         47
# Name: count, dtype: int64
#
# Column: insured_relationship
# Unique Values Count: 6
# Value Counts:
# insured_relationship
# own-child         165
# other-relative    164
# husband           156
# not-in-family     156
# wife              139
# unmarried         129
# Name: count, dtype: int64
#
# Column: capital-gains
# Unique Values Count: 312
# Value Counts:
# capital-gains
# 0        466
# 46300      5
# 51500      4
# 56700      3
# 51100      3
# 67800      3
# 55600      3
# 49900      3
# 52600      3
# 43700      3
# Name: count, dtype: int64
#
# Column: capital-loss
# Unique Values Count: 341
# Value Counts:
# capital-loss
#  0        432
# -50300      5
# -45300      4
# -31400      4
# -51000      4
# -61400      4
# -53800      4
# -31700      4
# -49200      4
# -66200      3
# Name: count, dtype: int64
#
# Column: incident_date
# Unique Values Count: 60
# Value Counts:
# incident_date
# 2015-02-02    25
# 2015-01-07    24
# 2015-02-17    23
# 2015-01-10    23
# 2015-02-04    23
# 2015-01-24    21
# 2015-01-08    21
# 2015-01-30    20
# 2015-01-19    20
# 2015-02-06    19
# Name: count, dtype: int64
#
# Column: incident_type
# Unique Values Count: 4
# Value Counts:
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                53
# Parked Car                   34
# Name: count, dtype: int64
#
# Column: collision_type
# Unique Values Count: 4
# Value Counts:
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                   87
# Name: count, dtype: int64
#
# Column: incident_severity
# Unique Values Count: 4
# Value Counts:
# incident_severity
# Minor Damage      304
# Total Loss        280
# Major Damage      276
# Trivial Damage     49
# Name: count, dtype: int64
#
# Column: authorities_contacted
# Unique Values Count: 4
# Value Counts:
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
#
# Column: incident_state
# Unique Values Count: 7
# Value Counts:
# incident_state
# NY    246
# SC    225
# WV    196
# NC     97
# VA     96
# PA     29
# OH     20
# Name: count, dtype: int64
#
# Column: incident_city
# Unique Values Count: 7
# Value Counts:
# incident_city
# Springfield    145
# Columbus       141
# Northbend      133
# Arlington      129
# Hillsdale      128
# Riverwood      121
# Northbrook     112
# Name: count, dtype: int64
#
# Column: incident_location
# Unique Values Count: 909
# Value Counts:
# incident_location
# 9935 4th Drive         1
# 8639 5th Hwy           1
# 4835 Britain Ridge     1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
# 3122 Apache Drive      1
# 9816 Britain St        1
# 8214 Flute St          1
# 6259 Lincoln Hwy       1
# Name: count, dtype: int64
#
# Column: incident_hour_of_the_day
# Unique Values Count: 24
# Value Counts:
# incident_hour_of_the_day
# 17    51
# 23    51
# 0     49
# 16    47
# 13    42
# 21    42
# 14    42
# 12    40
# 18    40
# 10    40
# Name: count, dtype: int64
#
# Column: number_of_vehicles_involved
# Unique Values Count: 4
# Value Counts:
# number_of_vehicles_involved
# 1    490
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
#
# Column: property_damage
# Unique Values Count: 3
# Value Counts:
# property_damage
# ?      329
# NO     304
# YES    276
# Name: count, dtype: int64
#
# Column: bodily_injuries
# Unique Values Count: 3
# Value Counts:
# bodily_injuries
# 2    309
# 0    307
# 1    293
# Name: count, dtype: int64
#
# Column: witnesses
# Unique Values Count: 4
# Value Counts:
# witnesses
# 2    234
# 0    230
# 1    228
# 3    217
# Name: count, dtype: int64
#
# Column: police_report_available
# Unique Values Count: 3
# Value Counts:
# police_report_available
# ?      316
# NO     307
# YES    286
# Name: count, dtype: int64
#
# Column: total_claim_amount
# Unique Values Count: 719
# Value Counts:
# total_claim_amount
# 59400    5
# 58500    4
# 60600    4
# 75400    4
# 70290    4
# 70400    4
# 44200    4
# 56160    3
# 69300    3
# 64800    3
# Name: count, dtype: int64
#
# Column: injury_claim
# Unique Values Count: 616
# Value Counts:
# injury_claim
# 0        24
# 5540      5
# 6340      5
# 13520     5
# 5000      4
# 4420      4
# 7420      4
# 6630      4
# 10540     4
# 5550      4
# Name: count, dtype: int64
#
# Column: property_claim
# Unique Values Count: 603
# Value Counts:
# property_claim
# 0        18
# 11080     5
# 10000     5
# 7000      4
# 11100     4
# 5720      4
# 860       4
# 9360      4
# 7040      4
# 10520     4
# Name: count, dtype: int64
#
# Column: vehicle_claim
# Unique Values Count: 691
# Value Counts:
# vehicle_claim
# 52080    5
# 33600    5
# 44800    5
# 41760    4
# 46800    4
# 42720    4
# 35000    4
# 41580    4
# 38850    4
# 45360    4
# Name: count, dtype: int64
#
# Column: auto_make
# Unique Values Count: 14
# Value Counts:
# auto_make
# Suburu       74
# Saab         72
# Dodge        72
# Nissan       69
# Ford         67
# BMW          67
# Chevrolet    66
# Audi         63
# Accura       63
# Toyota       62
# Name: count, dtype: int64
#
# Column: auto_model
# Unique Values Count: 39
# Value Counts:
# auto_model
# RAM           40
# Wrangler      38
# Jetta         33
# A3            33
# MDX           33
# Neon          32
# A5            30
# Legacy        30
# Passat        29
# Pathfinder    27
# Name: count, dtype: int64
#
# Column: auto_year
# Unique Values Count: 21
# Value Counts:
# auto_year
# 1995    52
# 2005    51
# 2006    51
# 1999    50
# 2007    48
# 2010    47
# 2009    47
# 2011    47
# 2003    46
# 2013    43
# Name: count, dtype: int64
#
# Column: fraud_reported
# Unique Values Count: 2
# Value Counts:
# fraud_reported
# N    668
# Y    241
# Name: count, dtype: int64

# %% [markdown]
# Following columns are likey identifiers - policy_number, incident_location, insured_zip, policy_bind_dates.tes
# tes
#  719

# %% [markdown]
# We keep the columns viz. policy_annual_premium & total_claim_amount considering they may have some predictive capability/usage.

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %%
# Identify and drop any columns that are completely empty
# No more columns that are empty as identifies in previous output

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %% [markdown]
# #### Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
#
# - We will look for illogical/invalid values only in features where negative values don't make business sense and these columns as identified by me are -
# - capital-gains, capital-loss - These can naturally be 0 or negative, depending on how the insurer calculates taxable gain/loss
# - injury_claim, property_claim, vehicle_claim, total_claim_amount - Should be greater than or equal to 0
# - number_of_vehicles_involved, bodily_injuries, witnesses - Should be greater than or equal to 0
# - Categorical Variables do not have a concept of negative/positive
# - Dates or strings may have formatting issues, but not invalid numeric signs

# %%
# List of columns that should only have positive or zero values
columns_to_check = ['total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses']

# Check if any of identified columns (listed in columns_to_check) have negative values
for col in columns_to_check:
    invalid_count = df[df[col] < 0].shape[0]
    if invalid_count > 0:
        print(f"{col}: {invalid_count} invalid entries found and removed.")
        df = df[df[col] >= 0]
    else:
        print(f"{col}: Ok")
# Out:
# total_claim_amount: Ok
# injury_claim: Ok
# property_claim: Ok
# vehicle_claim: Ok
# number_of_vehicles_involved: Ok
# bodily_injuries: Ok
# witnesses: Ok

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 5                 256   39         104594       2006-10-12           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 5    250/500               1000                1351.10               0
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 5       478456  ...         2                      NO              64100
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 5         6410           6410          51280       Saab         95      2003
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 5              Y
#
# [5 rows x 39 columns]

# %% [markdown]
# The following columns are likely Identifiers (High Cardinality, No Predictive Value | as identified earlier). These are unique to each record and may not help with classification:
# - policy_number : 909 unique values
# - incident_location : 909 unique values
# - insured_zip : 904 unique values
# - policy_bind_date : 865 unique dates

# %%
# Dropping earlier identified columns which are likely identifiers (high cardinality and possibility with no or low predictive value)

df.drop(['policy_number', 'incident_location', 'insured_zip', 'policy_bind_date'], axis=1, inplace=True)

# %%
# Show remaining columns
df.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 5                 256   39           OH    250/500               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 5                1351.10               0      FEMALE                     PhD
#
#   insured_occupation  ... witnesses police_report_available  \
# 0       craft-repair  ...         2                     YES
# 1  machine-op-inspct  ...         0                       ?
# 2              sales  ...         3                      NO
# 3       armed-forces  ...         2                      NO
# 5       tech-support  ...         2                      NO
#
#    total_claim_amount  injury_claim property_claim vehicle_claim  auto_make  \
# 0               71610          6510          13020         52080       Saab
# 1                5070           780            780          3510   Mercedes
# 2               34650          7700           3850         23100      Dodge
# 3               63400          6340           6340         50720  Chevrolet
# 5               64100          6410           6410         51280       Saab
#
#   auto_model auto_year fraud_reported
# 0        92x      2004              Y
# 1       E400      2007              Y
# 2        RAM      2007              N
# 3      Tahoe      2014              Y
# 5         95      2003              Y
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (909, 35)

# %%
# Check the dataset
df.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 5                 256   39           OH    250/500               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 5                1351.10               0      FEMALE                     PhD
#
#   insured_occupation  ... witnesses police_report_available  \
# 0       craft-repair  ...         2                     YES
# 1  machine-op-inspct  ...         0                       ?
# 2              sales  ...         3                      NO
# 3       armed-forces  ...         2                      NO
# 5       tech-support  ...         2                      NO
#
#    total_claim_amount  injury_claim property_claim vehicle_claim  auto_make  \
# 0               71610          6510          13020         52080       Saab
# 1                5070           780            780          3510   Mercedes
# 2               34650          7700           3850         23100      Dodge
# 3               63400          6340           6340         50720  Chevrolet
# 5               64100          6410           6410         51280       Saab
#
#   auto_model auto_year fraud_reported
# 0        92x      2004              Y
# 1       E400      2007              Y
# 2        RAM      2007              N
# 3      Tahoe      2014              Y
# 5         95      2003              Y
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 909 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           909 non-null    int64
#  1   age                          909 non-null    int64
#  2   policy_state                 909 non-null    object
#  3   policy_csl                   909 non-null    object
#  4   policy_deductable            909 non-null    int64
#  5   policy_annual_premium        909 non-null    float64
#  6   umbrella_limit               909 non-null    int64
#  7   insured_sex                  909 non-null    object
#  8   insured_education_level      909 non-null    object
#  9   insured_occupation           909 non-null    object
#  10  insured_hobbies              909 non-null    object
#  11  insured_relationship         909 non-null    object
#  12  capital-gains                909 non-null    int64
#  13  capital-loss                 909 non-null    int64
#  14  incident_date                909 non-null    object
#  15  incident_type                909 non-null    object
#  16  collision_type               909 non-null    object
#  17  incident_severity            909 non-null    object
#  18  authorities_contacted        909 non-null    object
#  19  incident_state               909 non-null    object
#  20  incident_city                909 non-null    object
#  21  incident_hour_of_the_day     909 non-null    int64
#  22  number_of_vehicles_involved  909 non-null    int64
#  23  property_damage              909 non-null    object
#  24  bodily_injuries              909 non-null    int64
#  25  witnesses                    909 non-null    int64
#  26  police_report_available      909 non-null    object
#  27  total_claim_amount           909 non-null    int64
#  28  injury_claim                 909 non-null    int64
#  29  property_claim               909 non-null    int64
#  30  vehicle_claim                909 non-null    int64
#  31  auto_make                    909 non-null    object
#  32  auto_model                   909 non-null    object
#  33  auto_year                    909 non-null    int64
#  34  fraud_reported               909 non-null    object
# dtypes: float64(1), int64(15), object(19)
# memory usage: 255.7+ KB

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
# Converting'incident_date' column to datetime format
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

# %%
# Check the features of the data again
print(df['incident_date'].dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put the target variable in y
y = df['fraud_reported']
# Put all the feature variables in X
X = df.drop('fraud_reported', axis=1)

# %%
y.head()
# Out:
# 0    Y
# 1    Y
# 2    N
# 3    Y
# 5    Y
# Name: fraud_reported, dtype: object

# %%
X.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 5                 256   39           OH    250/500               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 5                1351.10               0      FEMALE                     PhD
#
#   insured_occupation  ... bodily_injuries witnesses  police_report_available  \
# 0       craft-repair  ...               1         2                      YES
# 1  machine-op-inspct  ...               0         0                        ?
# 2              sales  ...               2         3                       NO
# 3       armed-forces  ...               1         2                       NO
# 5       tech-support  ...               0         2                       NO
#
#    total_claim_amount injury_claim property_claim vehicle_claim  auto_make  \
# 0               71610         6510          13020         52080       Saab
# 1                5070          780            780          3510   Mercedes
# 2               34650         7700           3850         23100      Dodge
# 3               63400         6340           6340         50720  Chevrolet
# 5               64100         6410           6410         51280       Saab
#
#   auto_model auto_year
# 0        92x      2004
# 1       E400      2007
# 2        RAM      2007
# 3      Tahoe      2014
# 5         95      2003
#
# [5 rows x 34 columns]

# %%
X.shape
# Out:
# (909, 34)

# %%
y.shape
# Out:
# (909,)

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (636, 34)

# %%
X_test.shape
# Out:
# (273, 34)

# %%
y_train.shape
# Out:
# (636,)

# %%
y_test.shape
# Out:
# (273,)

# %%
# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numeric_cols = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
print(numeric_cols)
# Out:
# ['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
X_train[numeric_cols].hist(bins=30, figsize=(16, 12))
plt.show()

# %% [markdown]
# The key observations from the above histograms are as follow.
# - The features that have have an imbalanced or skewed distribution
#     - umbrella_limit - most customers have a limit of '0' (right skewed)
#     - capital_gains - values clustered around '0' (right skewed)
#     - capital_loss - left skewed (values areound '0')
#     - others where we can see some mild right skew
#         - injury_claim
#         - property_claim
#         - vehicle claim
# - The following features have discrete peaks exhibiting catrogry like behaviour
#     - number_of_vehicles_involved
#     - bodily_injuries
#     - witnesses
#     - policy_deductable - only 3 values
#     - auto_year: Limited set of years
# - The following features are normally distributed
#     - policy_annual_premium
#     - total_claim_amount

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_train[numeric_cols].corr()
# Plot Heatmap of the correlation matrix
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlation Matrix", fontsize=12)
plt.show()

# %% [markdown]
# The following features are having a strong postive correlation
# - total_claim_amount & vehicle_claim - 0.98
# - months_as_customer & age - 0.92
# - total_claim_amount & injury_claim - 0.76
# - total_claim_amount & property_claim - 0.77
# - property_claim & injury_claim - 0.67

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
sns.countplot(x=y_train)
plt.title('Class Balance in y_train')
plt.xlabel('Fraud Reported')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We do observe a class imbalance which is not quite unusual in a problem like this.

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           636 non-null    int64
#  1   age                          636 non-null    int64
#  2   policy_state                 636 non-null    object
#  3   policy_csl                   636 non-null    object
#  4   policy_deductable            636 non-null    int64
#  5   policy_annual_premium        636 non-null    float64
#  6   umbrella_limit               636 non-null    int64
#  7   insured_sex                  636 non-null    object
#  8   insured_education_level      636 non-null    object
#  9   insured_occupation           636 non-null    object
#  10  insured_hobbies              636 non-null    object
#  11  insured_relationship         636 non-null    object
#  12  capital-gains                636 non-null    int64
#  13  capital-loss                 636 non-null    int64
#  14  incident_date                636 non-null    datetime64[ns]
#  15  incident_type                636 non-null    object
#  16  collision_type               636 non-null    object
#  17  incident_severity            636 non-null    object
#  18  authorities_contacted        636 non-null    object
#  19  incident_state               636 non-null    object
#  20  incident_city                636 non-null    object
#  21  incident_hour_of_the_day     636 non-null    int64
#  22  number_of_vehicles_involved  636 non-null    int64
#  23  property_damage              636 non-null    object
#  24  bodily_injuries              636 non-null    int64
#  25  witnesses                    636 non-null    int64
#  26  police_report_available      636 non-null    object
#  27  total_claim_amount           636 non-null    int64
#  28  injury_claim                 636 non-null    int64
#  29  property_claim               636 non-null    int64
#  30  vehicle_claim                636 non-null    int64
#  31  auto_make                    636 non-null    object
#  32  auto_model                   636 non-null    object
#  33  auto_year                    636 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(15), object(17)
# memory usage: 169.1+ KB

# %%
categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()
print(categorical_cols)
# Out:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def tgt_likelihood(df, feature, target='fraud_reported', plot=True):
    likelihood_df = df[[feature, target]].copy()
    likelihood_df[target] = likelihood_df[target].map({'Y': 1, 'N': 0})
    result = likelihood_df.groupby(feature)[target].mean().sort_values(ascending=False)
    
    print(f"Fraud Likelihood by '{feature}':")
    print(result.round(2))

# %%
tgt_likelihood(pd.concat([X_train, y_train], axis=1), 'insured_occupation')
# Out:
# Fraud Likelihood by 'insured_occupation':
# insured_occupation
# exec-managerial      0.40
# farming-fishing      0.38
# sales                0.31
# transport-moving     0.29
# craft-repair         0.29
# prof-specialty       0.29
# tech-support         0.28
# handlers-cleaners    0.24
# machine-op-inspct    0.24
# armed-forces         0.23
# protective-serv      0.20
# priv-house-serv      0.18
# adm-clerical         0.17
# other-service        0.17
# Name: fraud_reported, dtype: float64

# %%
tgt_likelihood(pd.concat([X_train, y_train], axis=1), 'insured_sex')
# Out:
# Fraud Likelihood by 'insured_sex':
# insured_sex
# MALE      0.32
# FEMALE    0.23
# Name: fraud_reported, dtype: float64

# %%
# Males have a higher fraud likelihood (32%) than females (23%), indicating gender may influence fraudulent claim tendencies slightly.

# %%
for col in categorical_cols:
    tgt_likelihood(pd.concat([X_train, y_train], axis=1), col)
# Out:
# Fraud Likelihood by 'policy_state':
# policy_state
# IN    0.30
# OH    0.28
# IL    0.22
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'policy_csl':
# policy_csl
# 250/500     0.30
# 100/300     0.28
# 500/1000    0.21
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'insured_sex':
# insured_sex
# MALE      0.32
# FEMALE    0.23
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'insured_education_level':
# insured_education_level
# JD             0.29
# Associate      0.28
# MD             0.28
# College        0.27
# PhD            0.27
# Masters        0.26
# High School    0.20
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'insured_occupation':
# insured_occupation
# exec-managerial      0.40
# farming-fishing      0.38
# sales                0.31
# transport-moving     0.29
# craft-repair         0.29
# prof-specialty       0.29
# tech-support         0.28
# handlers-cleaners    0.24
# machine-op-inspct    0.24
# armed-forces         0.23
# protective-serv      0.20
# priv-house-serv      0.18
# adm-clerical         0.17
# other-service        0.17
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'insured_hobbies':
# insured_hobbies
# chess             0.84
# cross-fit         0.83
# yachting          0.39
# polo              0.34
# skydiving         0.31
# base-jumping      0.30
# board-games       0.27
# sleeping          0.25
# reading           0.24
# hiking            0.22
# paintball         0.22
# bungie-jumping    0.20
# basketball        0.18
# video-games       0.18
# movies            0.17
# exercise          0.15
# dancing           0.12
# kayaking          0.11
# golf              0.11
# camping           0.09
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'insured_relationship':
# insured_relationship
# not-in-family     0.32
# other-relative    0.29
# wife              0.29
# husband           0.25
# unmarried         0.23
# own-child         0.21
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'incident_type':
# incident_type
# Single Vehicle Collision    0.29
# Multi-vehicle Collision     0.27
# Vehicle Theft               0.14
# Parked Car                  0.14
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'collision_type':
# collision_type
# Rear Collision     0.30
# Front Collision    0.29
# Side Collision     0.25
# ?                  0.14
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'incident_severity':
# incident_severity
# Major Damage      0.61
# Minor Damage      0.12
# Total Loss        0.12
# Trivial Damage    0.09
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'authorities_contacted':
# authorities_contacted
# Other        0.32
# Ambulance    0.29
# Fire         0.26
# Police       0.21
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'incident_state':
# incident_state
# OH    0.53
# PA    0.38
# NC    0.33
# SC    0.29
# VA    0.26
# NY    0.24
# WV    0.18
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'incident_city':
# incident_city
# Arlington      0.34
# Hillsdale      0.31
# Riverwood      0.25
# Springfield    0.25
# Columbus       0.25
# Northbend      0.23
# Northbrook     0.21
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'property_damage':
# property_damage
# YES    0.30
# ?      0.29
# NO     0.20
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'police_report_available':
# police_report_available
# NO     0.28
# ?      0.27
# YES    0.25
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'auto_make':
# auto_make
# Audi          0.33
# Chevrolet     0.33
# Volkswagen    0.31
# Mercedes      0.31
# Ford          0.30
# BMW           0.30
# Dodge         0.27
# Suburu        0.27
# Honda         0.25
# Nissan        0.24
# Toyota        0.24
# Accura        0.21
# Saab          0.20
# Jeep          0.14
# Name: fraud_reported, dtype: float64
# Fraud Likelihood by 'auto_model':
# auto_model
# Silverado         0.53
# X6                0.50
# C300              0.45
# M5                0.44
# Civic             0.40
# Jetta             0.38
# RAM               0.35
# F150              0.33
# A5                0.33
# Maxima            0.33
# Highlander        0.33
# A3                0.32
# Forrestor         0.32
# Tahoe             0.31
# Impreza           0.31
# ML350             0.30
# Escape            0.29
# X5                0.29
# Fusion            0.27
# TL                0.27
# Grand Cherokee    0.25
# E400              0.24
# 95                0.24
# 92x               0.24
# Corolla           0.23
# Ultima            0.23
# Passat            0.23
# Legacy            0.21
# MDX               0.21
# Accord            0.20
# Camry             0.19
# Pathfinder        0.18
# Neon              0.17
# CRV               0.17
# Malibu            0.13
# RSX               0.12
# 93                0.09
# Wrangler          0.08
# 3 Series          0.07
# Name: fraud_reported, dtype: float64

# %% [markdown]
# Key Intepretations
# - insured_sex - Males (32%) are more likely to report fraud than females (23%)
# - insured_education_level - JD(29%), Associate & MD holders show slightly higher fraud rates. High school is the lowest (20%)
# - insured_occupation - Fraud more likely in executive-managerial(40%) and farming-fishing(38%) roles. They are lowest in admin, other service (17%)
# - insured_hobbies - Hobbies like chess (84%), cross-fit (83%), yachting (39%) show unusually high fraud risk.
# - policy_state - Indiana (30%) and Ohio (28%) have higher fraud rates vs. Illinois (22%)
# - auto_make - Audi, Chevrolet, and Mercedes (≥31%) lead in fraud; Jeep is lowest (14%)
# - incident_type - Single Vehicle Collision (29%) is more fraud-prone than Vehicle Theft (14%)
# - collision_type - Rear and Front Collisions (~30%) more fraudulent than Side or unknown
# - incident_severity - Major Damage shows extremely high fraud likelihood (61%) vs. Total Loss and Minor Damage (~12%)
# - authorities_contacted - Other and Ambulance lead to more fraud cases (32%, 29%) compared to Police (21%)
# - incident_state - Ohio (53%) and Pennsylvania (38%) have highest fraud likelihoods

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
train_df = pd.concat([X_train, y_train], axis=1)
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=train_df, x='fraud_reported', y=col)
    plt.title(f'{col} vs Fraud Reported')
    plt.xlabel('Fraud Reported')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data

ROS = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ROS.fit_resample(X_train, y_train)
print(y_train_resampled.value_counts())
# Out:
# fraud_reported
# N    467
# Y    467
# Name: count, dtype: int64

# %%
# Classes are now balanced which is ideal for training models

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

def create_new_features(df):
    df['claim_to_premium_ratio'] = df['total_claim_amount'] / df['policy_annual_premium']
    df['total_individual_claims'] = df['injury_claim'] + df['property_claim'] + df['vehicle_claim']
    df['injury_ratio'] = df['injury_claim'] / df['total_claim_amount']
    df['is_late_night_incident'] = df['incident_hour_of_the_day'].apply(lambda x: 1 if (x >= 22 or x <= 5) else 0)
    df['incident_dayofweek'] = df['incident_date'].dt.dayofweek
    df['is_weekend'] = df['incident_dayofweek'].apply(lambda x: 1 if x >= 5 else 0)
    
    return df

X_train_resampled = create_new_features(X_train_resampled)
X_test = create_new_features(X_test)

# %%
X_train_resampled.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 266   44           IL    250/500                500
# 1                 272   43           OH    100/300               1000
# 2                 166   34           OH    100/300               1000
# 3                  94   26           IN    100/300                500
# 4                 284   48           IL   500/1000                500
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1611.83               0        MALE             High School
# 1                1279.13               0        MALE                     PhD
# 2                1083.72               0      FEMALE             High School
# 3                 722.66               0        MALE                      MD
# 4                 958.30               0      FEMALE                     PhD
#
#   insured_occupation  ... vehicle_claim   auto_make  auto_model  auto_year  \
# 0  handlers-cleaners  ...         26240         BMW    3 Series       2012
# 1       craft-repair  ...         58960        Audi          A3       2006
# 2  machine-op-inspct  ...         43920       Honda         CRV       2005
# 3    exec-managerial  ...         25690      Nissan  Pathfinder       2010
# 4  machine-op-inspct  ...         29820  Volkswagen      Passat       1998
#
#   claim_to_premium_ratio total_individual_claims injury_ratio  \
# 0              20.349541                   32800     0.100000
# 1              63.379015                   81070     0.090909
# 2              49.533090                   53680     0.090909
# 3              50.784601                   36700     0.100000
# 4              48.899092                   46860     0.181818
#
#   is_late_night_incident incident_dayofweek is_weekend
# 0                      1                  4          0
# 1                      1                  4          0
# 2                      0                  0          0
# 3                      0                  4          0
# 4                      0                  3          0
#
# [5 rows x 40 columns]

# %%
X_test.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 137   34           IN    250/500               1000
# 1                  72   29           OH   500/1000                500
# 2                 177   33           IL    100/300               1000
# 3                 289   47           OH   500/1000               2000
# 4                 256   39           OH    250/500               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1333.35               0        MALE                     PhD
# 1                 973.80               0      FEMALE               Associate
# 2                1609.67               0        MALE                 College
# 3                1102.29               0      FEMALE               Associate
# 4                1351.10               0      FEMALE                     PhD
#
#   insured_occupation  ... vehicle_claim auto_make      auto_model  auto_year  \
# 0     prof-specialty  ...         50050    Nissan      Pathfinder       2012
# 1       craft-repair  ...         52960     Dodge            Neon       2013
# 2       adm-clerical  ...         48300      Jeep  Grand Cherokee       2004
# 3       adm-clerical  ...         42000    Toyota      Highlander       1996
# 4       tech-support  ...         51280      Saab              95       2003
#
#   claim_to_premium_ratio total_individual_claims injury_ratio  \
# 0              58.986763                   78650     0.272727
# 1              67.981105                   66200     0.100000
# 2              51.439115                   82800     0.250000
# 3              48.988923                   54000     0.111111
# 4              47.442824                   64100     0.100000
#
#   is_late_night_incident incident_dayofweek is_weekend
# 0                      1                  1          0
# 1                      0                  4          0
# 2                      1                  1          0
# 3                      0                  5          1
# 4                      0                  4          0
#
# [5 rows x 40 columns]

# %%
X_train_resampled.shape
# Out:
# (934, 40)

# %%
X_train_resampled.shape
# Out:
# (934, 40)

# %%
X_train.shape
# Out:
# (636, 34)

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
columns_to_drop = ['months_as_customer', 'total_claim_amount', 'incident_dayofweek']
X_train_resampled.drop(columns=columns_to_drop, inplace=True, errors='ignore')
X_test.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %%
# Check the data
X_train_resampled.head()
# Out:
#    age policy_state policy_csl  policy_deductable  policy_annual_premium  \
# 0   44           IL    250/500                500                1611.83
# 1   43           OH    100/300               1000                1279.13
# 2   34           OH    100/300               1000                1083.72
# 3   26           IN    100/300                500                 722.66
# 4   48           IL   500/1000                500                 958.30
#
#    umbrella_limit insured_sex insured_education_level insured_occupation  \
# 0               0        MALE             High School  handlers-cleaners
# 1               0        MALE                     PhD       craft-repair
# 2               0      FEMALE             High School  machine-op-inspct
# 3               0        MALE                      MD    exec-managerial
# 4               0      FEMALE                     PhD  machine-op-inspct
#
#   insured_hobbies  ... property_claim  vehicle_claim   auto_make  auto_model  \
# 0          movies  ...           3280          26240         BMW    3 Series
# 1  bungie-jumping  ...          14740          58960        Audi          A3
# 2    base-jumping  ...           4880          43920       Honda         CRV
# 3         camping  ...           7340          25690      Nissan  Pathfinder
# 4        exercise  ...           8520          29820  Volkswagen      Passat
#
#   auto_year claim_to_premium_ratio total_individual_claims injury_ratio  \
# 0      2012              20.349541                   32800     0.100000
# 1      2006              63.379015                   81070     0.090909
# 2      2005              49.533090                   53680     0.090909
# 3      2010              50.784601                   36700     0.100000
# 4      1998              48.899092                   46860     0.181818
#
#   is_late_night_incident is_weekend
# 0                      1          0
# 1                      1          0
# 2                      0          0
# 3                      0          0
# 4                      0          0
#
# [5 rows x 37 columns]

# %%
X_train_resampled.shape
# Out:
# (934, 37)

# %%
X_test.shape
# Out:
# (273, 37)

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
def combine_categories(df, column, threshold=0.01):
    value_counts = df[column].value_counts(normalize=True)
    categories = value_counts[value_counts < threshold].index
    df[column] = df[column].replace(categories, 'Other')
    return df

cat = ['insured_occupation','insured_hobbies', 'auto_model', 'incident_city']

for col in cat:
    X_train_resampled = combine_categories(X_train_resampled, col)
    X_test = combine_categories(X_test, col)

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_columns = X_train_resampled.select_dtypes(include=['object']).columns.tolist()
print(categorical_columns)
# Out:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_encoded = pd.get_dummies(X_train_resampled, columns=categorical_columns, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_columns, drop_first=True)
X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)
print("Encoded training shape:", X_train_encoded.shape)
print("Encoded validation shape:", X_test_encoded.shape)
# Out:
# Encoded training shape: (934, 147)
# Encoded validation shape: (273, 147)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_test_encoded = pd.get_dummies(X_test, columns=categorical_columns, drop_first=True)
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)
print("Final validation shape after encoding:", X_test_encoded.shape)
# Out:
# Final validation shape after encoding: (273, 147)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train_resampled_encoded = y_train_resampled.map({'Y': 1, 'N': 0})
y_test_encoded = y_test.map({'Y': 1, 'N': 0})
print("Target value distribution after encoding (Train):")
print(y_train_resampled_encoded.value_counts())
# Create dummy variable for dependent feature in validation data
# Out:
# Target value distribution after encoding (Train):
# fraud_reported
# 0    467
# 1    467
# Name: count, dtype: int64

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
X_train_encoded.head()
# Out:
#    age  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0   44                500                1611.83               0
# 1   43               1000                1279.13               0
# 2   34               1000                1083.72               0
# 3   26                500                 722.66               0
# 4   48                500                 958.30               0
#
#    capital-gains  capital-loss incident_date  incident_hour_of_the_day  \
# 0              0             0    2015-01-02                         4
# 1              0             0    2015-02-06                         5
# 2          65600        -68200    2015-02-09                        18
# 3          50300             0    2015-01-23                         6
# 4          47900             0    2015-01-22                        19
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# 0                            1                1  ...                  False
# 1                            3                1  ...                  False
# 2                            1                0  ...                  False
# 3                            3                1  ...                   True
# 4                            3                0  ...                  False
#
#    auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0           False           False                 False          False
# 1           False           False                 False          False
# 2           False           False                 False          False
# 3           False           False                 False          False
# 4           False           False                 False          False
#
#    auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0             False              False                False          False
# 1             False              False                False          False
# 2             False              False                False          False
# 3             False              False                False          False
# 4             False              False                False          False
#
#    auto_model_X6
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 147 columns]

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# Scale the numeric features present in the training data
scaler = StandardScaler()

# Scale the numeric features present in the validation data

# 1. Specifying the numeric columns | 2. Fitting the scaler on training data and transforming | 3. Transform the validation data | 
numeric_cols_encoded = X_train_encoded.select_dtypes(include=['int64', 'float64']).columns.tolist()
X_train_encoded[numeric_cols_encoded] = scaler.fit_transform(X_train_encoded[numeric_cols_encoded])
X_test_encoded[numeric_cols_encoded] = scaler.transform(X_test_encoded[numeric_cols_encoded])

# %%
X_train_encoded.head()
# Out:
#         age  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0  0.578709          -1.034734               1.528875       -0.486261
# 1  0.470736          -0.225319               0.111085       -0.486261
# 2 -0.501024          -0.225319              -0.721649       -0.486261
# 3 -1.364810          -1.034734              -2.260295       -0.486261
# 4  1.010602          -1.034734              -1.256123       -0.486261
#
#    capital-gains  capital-loss incident_date  incident_hour_of_the_day  \
# 0      -0.831162      0.948514    2015-01-02                 -1.161845
# 1      -0.831162      0.948514    2015-02-06                 -1.015182
# 2       1.582031     -1.473583    2015-02-09                  0.891444
# 3       1.019198      0.948514    2015-01-23                 -0.868518
# 4       0.930910      0.948514    2015-01-22                  1.038108
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# 0                    -0.856260        -0.037159  ...                  False
# 1                     1.077831        -0.037159  ...                  False
# 2                    -0.856260        -1.233945  ...                  False
# 3                     1.077831        -0.037159  ...                   True
# 4                     1.077831        -1.233945  ...                  False
#
#    auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0           False           False                 False          False
# 1           False           False                 False          False
# 2           False           False                 False          False
# 3           False           False                 False          False
# 4           False           False                 False          False
#
#    auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0             False              False                False          False
# 1             False              False                False          False
# 2             False              False                False          False
# 3             False              False                False          False
# 4             False              False                False          False
#
#    auto_model_X6
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 147 columns]

# %%
X_test_encoded.head()
# Out:
#         age  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0 -0.501024          -0.225319               0.342141       -0.486261
# 1 -1.040890          -1.034734              -1.190070       -0.486261
# 2 -0.608997          -0.225319               1.519671       -0.486261
# 3  0.902629           1.393510              -0.642514       -0.486261
# 4  0.038843          -0.225319               0.417782       -0.486261
#
#    capital-gains  capital-loss incident_date  incident_hour_of_the_day  \
# 0      -0.831162     -1.786112    2015-01-13                 -1.748499
# 1      -0.831162     -2.102192    2015-01-16                 -0.428528
# 2      -0.831162      0.479721    2015-01-20                  1.478098
# 3       1.854251     -0.397490    2015-01-31                  0.451454
# 4      -0.831162      0.948514    2015-01-02                  1.038108
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# 0                     1.077831        -1.233945  ...                   True
# 1                    -0.856260        -0.037159  ...                  False
# 2                    -0.856260        -0.037159  ...                  False
# 3                    -0.856260        -0.037159  ...                  False
# 4                     1.077831        -1.233945  ...                  False
#
#    auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0           False           False                 False          False
# 1           False           False                 False          False
# 2           False           False                 False          False
# 3           False           False                 False          False
# 4           False           False                 False          False
#
#    auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0             False              False                False          False
# 1             False              False                False          False
# 2             False              False                False          False
# 3             False              False                False          False
# 4             False              False                False          False
#
#    auto_model_X6
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 147 columns]

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
X_train_encoded = X_train_encoded.drop(columns=['incident_date'], errors='ignore')
X_test_encoded = X_test_encoded.drop(columns=['incident_date'], errors='ignore')

# %%
# Apply RFECV to identify the most relevant features
log_reg = LogisticRegression(max_iter=1000, random_state=42)
cv = StratifiedKFold(n_splits=5)

rfecv = RFECV(estimator=log_reg, step=1, cv=cv, scoring='accuracy', n_jobs=-1)
rfecv.fit(X_train_encoded, y_train_resampled_encoded)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=LogisticRegression(max_iter=1000, random_state=42), n_jobs=-1,
#       scoring='accuracy')

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranking = pd.DataFrame({'Feature': X_train_encoded.columns, 'Ranking': rfecv.ranking_}).sort_values(by='Ranking')
print("\nFeature Rankings by RFECV:")
print(feature_ranking)
# Out:
# Feature Rankings by RFECV:
#                              Feature  Ranking
# 48         insured_hobbies_cross-fit        1
# 73    incident_severity_Minor Damage        1
# 74      incident_severity_Total Loss        1
# 75  incident_severity_Trivial Damage        1
# 47             insured_hobbies_chess        1
# ..                               ...      ...
# 40          insured_occupation_sales      138
# 1                  policy_deductable      139
# 97               auto_make_Chevrolet      140
# 82                 incident_state_SC      141
# 45    insured_hobbies_bungie-jumping      142
#
# [146 rows x 2 columns]

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_train_encoded.columns[rfecv.support_].tolist()
print(f'Columns selected by RFECV: {col}')
# Out:
# Columns selected by RFECV: ['insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage']

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_train_selected = X_train_encoded[col]
X_test_selected = X_test_encoded[col]

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_train_selected_sm = sm.add_constant(X_train_selected)

# Check the data
X_train_selected_sm.shape
# Out:
# (934, 6)

# %%
X_train_selected_sm.columns.tolist()
# Out:
# ['const',
#  'insured_hobbies_chess',
#  'insured_hobbies_cross-fit',
#  'incident_severity_Minor Damage',
#  'incident_severity_Total Loss',
#  'incident_severity_Trivial Damage']

# %%
X_train_selected_sm.head()
# Out:
#    const  insured_hobbies_chess  insured_hobbies_cross-fit  \
# 0    1.0                  False                      False
# 1    1.0                  False                      False
# 2    1.0                  False                      False
# 3    1.0                  False                      False
# 4    1.0                  False                      False
#
#    incident_severity_Minor Damage  incident_severity_Total Loss  \
# 0                           False                          True
# 1                            True                         False
# 2                           False                          True
# 3                           False                         False
# 4                           False                         False
#
#    incident_severity_Trivial Damage
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
X_train_selected_sm.dtypes
# Out:
# const                               float64
# insured_hobbies_chess                  bool
# insured_hobbies_cross-fit              bool
# incident_severity_Minor Damage         bool
# incident_severity_Total Loss           bool
# incident_severity_Trivial Damage       bool
# dtype: object

# %%
X_train_selected_sm = X_train_selected_sm.astype(float)
y_train_resampled_encoded = y_train_resampled_encoded.astype(int)

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
logit_model = sm.Logit(y_train_resampled_encoded, X_train_selected_sm)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.411460
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  934
# Model:                          Logit   Df Residuals:                      928
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 30 Apr 2025   Pseudo R-squ.:                  0.4064
# Time:                        17:29:59   Log-Likelihood:                -384.30
# converged:                       True   LL-Null:                       -647.40
# Covariance Type:            nonrobust   LLR p-value:                1.770e-111
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                1.3377      0.129     10.381      0.000       1.085       1.590
# insured_hobbies_chess                4.1716      0.491      8.498      0.000       3.209       5.134
# insured_hobbies_cross-fit            4.2970      0.541      7.936      0.000       3.236       5.358
# incident_severity_Minor Damage      -3.2223      0.233    -13.853      0.000      -3.678      -2.766
# incident_severity_Total Loss        -3.2939      0.247    -13.329      0.000      -3.778      -2.810
# incident_severity_Trivial Damage    -3.3253      0.511     -6.502      0.000      -4.328      -2.323
# ====================================================================================================

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# My inferences from the model that has been built -
# - The model was built using 5 key features selected via RFECV and achieved a Pseudo R² of 0.4064, indicating good explanatory power for fraud detection.
# - All selected features are statistically significant (p < 0.001) and contribute meaningfully to predicting fraudulent claims.
# - Hobbied - Customers listing chess or cross-fit as hobbies show a higher likelihood of fraud. These hobbies may be proxies for behavioral traits or demographic segments needing closer fraud scrutiny.
# - Incident_Severity - Claims labeled as Minor Damage, Total Loss, or Trivial Damage are significantly less likely to be fraudulent. This suggests that fraud is more common in moderate, ambiguous claim scenarios, rather than clear-cut severe damage.
# - The model provides, interpretable insights that can help insurance companies prioritize fraud investigations more effectively.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
vif_df = pd.DataFrame()
vif_df["Feature"] = X_train_selected_sm.columns
vif_df["VIF"] = [variance_inflation_factor(X_train_selected_sm.values, i)
                 for i in range(X_train_selected_sm.shape[1])]

print(vif_df)
# Out:
#                             Feature       VIF
# 0                             const  2.406924
# 1             insured_hobbies_chess  1.024622
# 2         insured_hobbies_cross-fit  1.012996
# 3    incident_severity_Minor Damage  1.216424
# 4      incident_severity_Total Loss  1.200343
# 5  incident_severity_Trivial Damage  1.061240

# %% [markdown]
# Inferences -
# - All VIF values are very close to 1 and hence I feel no multicollinearity problem exists
# - Hence i feel there is no need to drop or transform any features
# - The model seems to be statistically clean -
#     - Reasonably good p-values
#     - Acceptable VIFs
#     - Good pseudo-R²

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_probs = result.predict(X_train_selected_sm)

# Reshape it into an array
y_train_probs = y_train_probs.values.reshape(-1)

print("First 5 predicted probabilities:")
print(y_train_probs[:5])
# Out:
# First 5 predicted probabilities:
# [0.12387987 0.13186466 0.12387987 0.79211943 0.79211943]

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
train_pred_df = pd.DataFrame({'Actual_Fraud': y_train_resampled_encoded, 'Predicted_Prob': y_train_probs})

# Create new column indicating predicted classifications based on a cutoff value of 0.5
train_pred_df['Predicted_Label'] = train_pred_df['Predicted_Prob'].apply(lambda x: 1 if x >= 0.5 else 0)

print(train_pred_df.head())
# Out:
#    Actual_Fraud  Predicted_Prob  Predicted_Label
# 0             0        0.123880                0
# 1             1        0.131865                0
# 2             0        0.123880                0
# 3             0        0.792119                1
# 4             0        0.792119                1

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
accuracy = metrics.accuracy_score(train_pred_df['Actual_Fraud'], train_pred_df['Predicted_Label'])
print(accuracy)
# Out:
# 0.8576017130620985

# %%
# Training Accuracy of the Logistic Regression model is 0.86

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(train_pred_df['Actual_Fraud'], train_pred_df['Predicted_Label'])
print(conf_matrix)
# Out:
# [[386  81]
#  [ 52 415]]

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.show()

# %% [markdown]
# Inferences from the Confusion Matrix-
# - Model correctly predicted 386 genuine (non-fraud) claims (True Negatives) & 415 fraudulent claims (True Positives)
# - There were 81 False Positives where genuine claims were incorrectly flagged as fraud
# - There were 52 False Negatives where fraudulent claims were missed by the model
# - Good overall balance, with slightly more False Positives than False Negatives

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = metrics.confusion_matrix(train_pred_df['Actual_Fraud'], train_pred_df['Predicted_Label']).ravel()
print(f"True Positives: {tp}")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
# Out:
# True Positives: 415
# True Negatives: 386
# False Positives: 81
# False Negatives: 52

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print(f'Sensitivity: {sensitivity:.4f}')

# Calculate the specificity
specificity = tn / (tn + fp)
print(f'Specificity: {specificity:.4f}')

# Calculate Precision
precision = tp / (tp + fp)
print(f'Precision: {precision:.4f}')

# Calculate Recall
recall = sensitivity  # for clarity
print(f'Recall: {recall:.4f}')

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f'F1 Score: {f1_score:.4f}')
# Out:
# Sensitivity: 0.8887
# Specificity: 0.8266
# Precision: 0.8367
# Recall: 0.8887
# F1 Score: 0.8619

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Define ROC function
def plot_roc_curve(y_true, y_prob, model_name='Model'):
    fpr, tpr, thresholds = roc_curve(y_true, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {roc_auc:.4f})', color='darkorange', lw=2)
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # diagonal line
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return roc_auc

# %%
# Call the ROC function
auc_score = plot_roc_curve(train_pred_df['Actual_Fraud'], y_train_probs, model_name='Logistic Regression')
print(f"AUC Score: {auc_score:.4f}")
# Out:
# AUC Score: 0.8712

# %% [markdown]
# Inferences -
#  - The ROC curve shows the model's ability to separate fraudulent and non-fraudulent claims across all thresholds. The curve rises sharply, indicating high sensitivity with low false positive rates
#  - An AUC score of 0.8712 implies excellent model performance — the model has an 87.1% chance of ranking a random fraud case higher than a non-fraud case
#  - The model performs significantly better than random guessing (AUC = 0.5), confirming strong discriminatory power.

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoffs = np.arange(0.1, 0.91, 0.05)

accuracy_list = []
sensitivity_list = []
specificity_list = []

for cutoff in cutoffs:
    predicted = [1 if prob >= cutoff else 0 for prob in y_train_probs]
    tn, fp, fn, tp = metrics.confusion_matrix(train_pred_df['Actual_Fraud'], predicted).ravel()
    
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    accuracy_list.append(accuracy)
    sensitivity_list.append(sensitivity)
    specificity_list.append(specificity)

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
cutoff_df = pd.DataFrame({
    'Cutoff': cutoffs,
    'Accuracy': accuracy_list,
    'Sensitivity': sensitivity_list,
    'Specificity': specificity_list
})

print(cutoff_df)
# Out:
#     Cutoff  Accuracy  Sensitivity  Specificity
# 0     0.10  0.500000     1.000000     0.000000
# 1     0.15  0.857602     0.888651     0.826552
# 2     0.20  0.857602     0.888651     0.826552
# 3     0.25  0.857602     0.888651     0.826552
# 4     0.30  0.857602     0.888651     0.826552
# 5     0.35  0.857602     0.888651     0.826552
# 6     0.40  0.857602     0.888651     0.826552
# 7     0.45  0.857602     0.888651     0.826552
# 8     0.50  0.857602     0.888651     0.826552
# 9     0.55  0.857602     0.888651     0.826552
# 10    0.60  0.857602     0.888651     0.826552
# 11    0.65  0.857602     0.888651     0.826552
# 12    0.70  0.857602     0.888651     0.826552
# 13    0.75  0.857602     0.888651     0.826552
# 14    0.80  0.620985     0.261242     0.980728
# 15    0.85  0.620985     0.261242     0.980728
# 16    0.90  0.616702     0.252677     0.980728

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))
plt.plot(cutoff_df['Cutoff'], cutoff_df['Accuracy'], label='Accuracy', marker='o')
plt.plot(cutoff_df['Cutoff'], cutoff_df['Sensitivity'], label='Sensitivity', marker='s')
plt.plot(cutoff_df['Cutoff'], cutoff_df['Specificity'], label='Specificity', marker='^')

plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Model Performance vs Cutoff')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Inferences -
#  - Accuracy remains consistently high (~86%) across a wide cutoff range (0.2 to 0.75).
#  - Sensitivity (true fraud detection) is also stable and high (~89%) in this range.
#  - Specificity improves at higher cutoffs but causes a sharp drop in sensitivity.
#  - An optimal cutoff between 0.3 and 0.5 balances accuracy, sensitivity, and specificity effectively for fraud detection.

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_cutoff = 0.4
train_pred_df['Final_Prediction'] = train_pred_df['Predicted_Prob'].apply(lambda x: 1 if x >= optimal_cutoff else 0)
print(train_pred_df[['Actual_Fraud', 'Predicted_Prob', 'Final_Prediction']].head())
# Out:
#    Actual_Fraud  Predicted_Prob  Final_Prediction
# 0             0        0.123880                 0
# 1             1        0.131865                 0
# 2             0        0.123880                 0
# 3             0        0.792119                 1
# 4             0        0.792119                 1

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
final_accuracy = metrics.accuracy_score(train_pred_df['Actual_Fraud'], train_pred_df['Final_Prediction'])
print(f'Accuracy using optimal cutoff (0.4): {final_accuracy:.4f}')
# Out:
# Accuracy using optimal cutoff (0.4): 0.8576

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
final_conf_matrix = metrics.confusion_matrix(train_pred_df['Actual_Fraud'], train_pred_df['Final_Prediction'])

print("Confusion Matrix (cutoff = 0.4):")
print(final_conf_matrix)

plt.figure(figsize=(6, 4))
sns.heatmap(final_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix at Cutoff 0.4')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.tight_layout()
plt.show()
# Out:
# Confusion Matrix (cutoff = 0.4):
# [[386  81]
#  [ 52 415]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_final, fp_final, fn_final, tp_final = metrics.confusion_matrix(
    train_pred_df['Actual_Fraud'],
    train_pred_df['Final_Prediction']
).ravel()

# Display the results
print(f"True Positives: {tp_final}")
print(f"True Negatives: {tn_final}")
print(f"False Positives: {fp_final}")
print(f"False Negatives: {fn_final}")
# Out:
# True Positives: 415
# True Negatives: 386
# False Positives: 81
# False Negatives: 52

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity_final = tp_final / (tp_final + fn_final)
print(f'Sensitivity: {sensitivity_final:.4f}')

# Calculate the specificity
specificity_final = tn_final / (tn_final + fp_final)
print(f'Specificity: {specificity_final:.4f}')

# Calculate Precision
precision_final = tp_final / (tp_final + fp_final)
print(f'Precision: {precision_final:.4f}')

# Calculate Recall
recall_final = sensitivity_final
print(f'Recall: {recall_final:.4f}')

# Calculate F1 Score
f1_score_final = 2 * (precision_final * recall_final) / (precision_final + recall_final)
print(f'F1 Score: {f1_score_final:.4f}')
# Out:
# Sensitivity: 0.8887
# Specificity: 0.8266
# Precision: 0.8367
# Recall: 0.8887
# F1 Score: 0.8619

# %% [markdown]
# Inferences -
# - THe model achieves a high sensitivity of 88.87%, indicating strong ability to detect actual fraud cases
# - A specificity of 82.66% shows good capability in correctly identifying genuine claims
# - Precision of 83.67% suggests that most flagged frauds are indeed true frauds
# - Recall matches sensitivity, reinforcing the model's robustness in fraud detection
# - An F1 Score of 86.19% confirms a well-balanced performance between precision and recall, ideal for fraud investigation efficiency.

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
precision_vals, recall_vals, thresholds = precision_recall_curve(train_pred_df['Actual_Fraud'], train_pred_df['Predicted_Prob'])

plt.figure(figsize=(8, 5))
plt.plot(recall_vals, precision_vals, label='Precision-Recall Curve', color='teal')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Inferences -
# - The curve maintains high precision (>85%) across a wide range of recall values, indicating the model reliably identifies true frauds
# - Precision begins to drop sharply only when recall approaches 1, suggesting some trade-off at very high sensitivity
# - The model strikes a good balance between catching frauds and avoiding false alarms across practical thresholds

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_base = RandomForestClassifier(random_state=42)
rf_base.fit(X_train_encoded, y_train_resampled_encoded)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
importances = rf_base.feature_importances_

# Create a DataFrame to visualise the importance scores
feature_importance_df = pd.DataFrame({'Feature': X_train_encoded.columns, 'Importance': importances}).sort_values(by='Importance', ascending=False)

# Display top features
print(feature_importance_df.head(10))
# Out:
#                            Feature  Importance
# 74    incident_severity_Total Loss    0.061929
# 73  incident_severity_Minor Damage    0.053028
# 15         total_individual_claims    0.038720
# 12                   vehicle_claim    0.037774
# 11                  property_claim    0.034882
# 2            policy_annual_premium    0.034543
# 14          claim_to_premium_ratio    0.034247
# 6         incident_hour_of_the_day    0.033293
# 0                              age    0.030718
# 10                    injury_claim    0.029478

# %%
# Select features with high importance scores
selected_features_rf = feature_importance_df[feature_importance_df['Importance'] > 0.01]['Feature'].tolist()
print(f"Selected {len(selected_features_rf)} features with importance > 0.01")
# Create a new training data with only the selected features
X_train_rf_selected = X_train_encoded[selected_features_rf]
X_train_rf_selected.shape
# Out:
# Selected 20 features with importance > 0.01
# (934, 20)

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_refined = RandomForestClassifier(random_state=42)
rf_refined.fit(X_train_rf_selected, y_train_resampled_encoded)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_rf_pred_probs = rf_refined.predict_proba(X_train_rf_selected)[:, 1]
y_train_rf_preds = rf_refined.predict(X_train_rf_selected)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
rf_accuracy = accuracy_score(y_train_resampled_encoded, y_train_rf_preds)
rf_accuracy
# Out:
# 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_matrix_rf = confusion_matrix(y_train_resampled_encoded, y_train_rf_preds)
print("Confusion Matrix (Training Data):")
conf_matrix_rf
# Out:
# Confusion Matrix (Training Data):
# array([[467,   0],
#        [  0, 467]], dtype=int64)

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_rf, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Random Forest - Confusion Matrix (Training Data)')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf, fp_rf, fn_rf, tp_rf = confusion_matrix(y_train_resampled_encoded, y_train_rf_preds).ravel()

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf = tp_rf / (tp_rf + fn_rf)
print(f'Sensitivity: {sensitivity_rf:.4f}')

# Calculate the specificity
specificity_rf = tn_rf / (tn_rf + fp_rf)
print(f'Specificity: {specificity_rf:.4f}')

# Calculate Precision
precision_rf = tp_rf / (tp_rf + fp_rf)
print(f'Precision: {precision_rf:.4f}')

# Calculate Recall
recall_rf = sensitivity_rf
print(f'Recall: {recall_rf:.4f}')

# Calculate F1 Score
f1_rf = 2 * (precision_rf * recall_rf) / (precision_rf + recall_rf)
print(f'F1 Score: {f1_rf:.4f}')
# Out:
# Sensitivity: 1.0000
# Specificity: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores_rf = cross_val_score(rf_refined, X_train_rf_selected, y_train_resampled_encoded, cv=5, scoring='accuracy')
cv_scores_rf
# Out:
# array([0.84491979, 0.90374332, 0.94117647, 0.92513369, 0.96236559])

# %%
cv_scores_rf.mean()
# Out:
# 0.915467770685987

# %% [markdown]
# Inference
# - The model’s mean CV accuracy is 91.55%, suggesting strong generalization performance
# - The individual fold scores are high (84.5% to 96.2%), with limited variance
# - While training accuracy was 100%, the CV result indicates overfitting, but overall model robustness looks high

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
grid_param = {
    'n_estimators': [50, 75, 100],
    'max_depth': [5, 10],
    'min_samples_split': [5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

rf_model = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(estimator=rf_model, param_grid=grid_param, cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

grid_search.fit(X_train_rf_selected, y_train_resampled_encoded)

# Best Hyperparameters
print('Best Parameters:', grid_search.best_params_)
print(f'Best CV Accuracy: {grid_search.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Best CV Accuracy: 0.9090

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_final = RandomForestClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=2, min_samples_split=5, n_estimators=50, random_state=42)
rf_final.fit(X_train_rf_selected, y_train_resampled_encoded)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_rf_final_preds = rf_final.predict(X_train_rf_selected)
y_train_rf_final_probs = rf_final.predict_proba(X_train_rf_selected)[:, 1]

# %%
y_train_rf_final_preds[:5]
# Out:
# array([0, 1, 0, 0, 0])

# %%
y_train_rf_final_probs[:5]
# Out:
# array([0.11525634, 0.52691939, 0.11968599, 0.47114708, 0.33980064])

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
rf_final_accuracy = accuracy_score(y_train_resampled_encoded, y_train_rf_final_preds)
rf_final_accuracy
# Out:
# 0.9721627408993576

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_final = confusion_matrix(y_train_resampled_encoded, y_train_rf_final_preds)
conf_matrix_rf_final

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_rf_final, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Final Tuned Random Forest - Confusion Matrix (Training Data)')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf_final, fp_rf_final, fn_rf_final, tp_rf_final = conf_matrix_rf_final.ravel()

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf_final = tp_rf_final / (tp_rf_final + fn_rf_final)
print(f'Sensitivity: {sensitivity_rf_final:.4f}')

# Calculate the specificity
specificity_rf_final = tn_rf_final / (tn_rf_final + fp_rf_final)
print(f'Specificity: {specificity_rf_final:.4f}')

# Calculate Precision
precision_rf_final = tp_rf_final / (tp_rf_final + fp_rf_final)
print(f'Precision: {precision_rf_final:.4f}')

# Calculate Recall
recall_rf_final = sensitivity_rf_final
print(f'Recall: {recall_rf_final:.4f}')

# Calculate F1-Score
f1_rf_final = 2 * (precision_rf_final * recall_rf_final) / (precision_rf_final + recall_rf_final)
print(f'F1 Score: {f1_rf_final:.4f}')
# Out:
# Sensitivity: 1.0000
# Specificity: 0.9443
# Precision: 0.9473
# Recall: 1.0000
# F1 Score: 0.9729

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_val_encoded = pd.get_dummies(X_test)
logistic_selected_features = [
    'insured_hobbies_chess',
    'insured_hobbies_cross-fit',
    'incident_severity_Minor Damage',
    'incident_severity_Total Loss',
    'incident_severity_Trivial Damage'
]
for col in logistic_selected_features:
    if col not in X_val_encoded.columns:
        X_val_encoded[col] = 0
X_val_logistic_selected = X_val_encoded[logistic_selected_features]

# Add constant to X_validation
X_val_logistic_selected_sm = sm.add_constant(X_val_logistic_selected)
X_val_logistic_selected_sm.head()
# Out:
#    const  insured_hobbies_chess  insured_hobbies_cross-fit  \
# 0    1.0                  False                      False
# 1    1.0                  False                      False
# 2    1.0                  False                      False
# 3    1.0                  False                      False
# 4    1.0                  False                      False
#
#    incident_severity_Minor Damage  incident_severity_Total Loss  \
# 0                            True                         False
# 1                           False                         False
# 2                           False                         False
# 3                            True                         False
# 4                           False                         False
#
#    incident_severity_Trivial Damage
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False

# %%
X_val_logistic_selected_sm = X_val_logistic_selected_sm.astype(float)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_validation_pred = result.predict(X_val_logistic_selected_sm)
y_validation_pred.head()
# Out:
# 0    0.131865
# 1    0.792119
# 2    0.792119
# 3    0.131865
# 4    0.792119
# dtype: float64

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
val_pred_df = pd.DataFrame({'Actual_Fraud': y_test.map({'N': 0, 'Y': 1}), 'Predicted_Prob': y_validation_pred})
val_pred_df.head()
# Out:
#    Actual_Fraud  Predicted_Prob
# 0             0        0.131865
# 1             0        0.792119
# 2             1        0.792119
# 3             0        0.131865
# 4             1        0.792119

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
optimal_cutoff = 0.4
val_pred_df['Final_Prediction'] = val_pred_df['Predicted_Prob'].apply(lambda x: 1 if x >= optimal_cutoff else 0)
val_pred_df.head()
# Out:
#    Actual_Fraud  Predicted_Prob  Final_Prediction
# 0             0        0.131865                 0
# 1             0        0.792119                 1
# 2             1        0.792119                 1
# 3             0        0.131865                 0
# 4             1        0.792119                 1

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
val_accuracy = accuracy_score(val_pred_df['Actual_Fraud'], val_pred_df['Final_Prediction'])
val_accuracy
# Out:
# 0.8424908424908425

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
val_conf_matrix = confusion_matrix(val_pred_df['Actual_Fraud'], val_pred_df['Final_Prediction'])
val_conf_matrix

plt.figure(figsize=(6, 4))
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Logistic Regression (Validation Set)')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = val_conf_matrix.ravel()

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print(sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print(specificity)

# Calculate Precision
precision = tp / (tp + fp)
print(precision)

# Calculate Recall
recall = sensitivity
print(recall)

# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)
print(f1)
# Out:
# 0.9027777777777778
# 0.8208955223880597
# 0.6435643564356436
# 0.9027777777777778
# 0.7514450867052024

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_test_encoded = pd.get_dummies(X_test)
selected_features_rf = feature_importance_df[feature_importance_df['Importance'] > 0.01]['Feature'].tolist()
for col in selected_features_rf:
    if col not in X_test_encoded.columns:
        X_test_encoded[col] = 0
X_val_rf_selected = X_test_encoded[selected_features_rf]

# Make predictions on the validation data
y_val_rf_pred = rf_final.predict(X_val_rf_selected)
y_val_rf_probs = rf_final.predict_proba(X_val_rf_selected)[:, 1]

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
val_rf_accuracy = accuracy_score(y_test.map({'N': 0, 'Y': 1}), y_val_rf_pred)
val_rf_accuracy
# Out:
# 0.7692307692307693

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
val_rf_conf_matrix = confusion_matrix(y_test.map({'N': 0, 'Y': 1}), y_val_rf_pred)
val_rf_conf_matrix

plt.figure(figsize=(6, 4))
sns.heatmap(val_rf_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Random Forest - Confusion Matrix (Validation Set)')
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_rf, fp_rf, fn_rf, tp_rf = val_rf_conf_matrix.ravel()

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity_rf = tp_rf / (tp_rf + fn_rf)
print(sensitivity_rf)

# Calculate Specificity
specificity_rf = tn_rf / (tn_rf + fp_rf)
print(specificity_rf)

# Calculate Precision
precision_rf = tp_rf / (tp_rf + fp_rf)
print(precision_rf)

# Calculate Recall
recall_rf = sensitivity_rf
print(recall_rf)

# Calculate F1-score
f1_rf = 2 * (precision_rf * recall_rf) / (precision_rf + recall_rf)
print(f1_rf)
# Out:
# 0.3333333333333333
# 0.9253731343283582
# 0.6153846153846154
# 0.3333333333333333
# 0.43243243243243246

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.

# %% [markdown]
# ### Key Observations
#
# - Logistic Regression performed well with interpretable results and minimal overfitting, but its performance slightly lagged in precision and F1
# - Random Forest offered better accuracy, precision, and F1 score, and handled complex patterns more effectively
# - Feature importance from Random Forest added business insight into what contributes to fraud risk
# - Overfitting concerns were mitigated through hyperparameter tuning and cross-validation, ensuring robust Random Forest performance.
#
# ### REcommendations
#
# - Use Random Forest as the primary fraud detection model, given its superior accuracy and balanced performance across metrics
# - Keep Logistic Regression as a secondary interpretable model for audit trails and explainability, especially in regulatory reviews
# - Integrate both into a layered decision-support system, where Random Forest flags likely fraud and Logistic Regression provides rationale.
